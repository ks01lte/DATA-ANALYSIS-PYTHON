# %% [markdown]
# # 우리동네의 인구구조와 가장 비슷한 지역은 어디일까?

# %%
import csv 
f = open('age.csv')
data = csv.reader(f)
next(data)

home = [] #입력받은 지역의 데이터를 저장할 리스트 생성
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data :
    if name in row[0] :
        for i in row[3:] :
            home.append(int(i))

print(home)
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import numpy as np
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype=int) #numpy활용해 수정

print(home)
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림
# [326 334 406 413 389 408 417 434 411 387 420 383 354 357 340 338 349 339
#  407 380 390 453 424 516 451 466 448 484 471 476 558 541 579 619 638 740
#  756 792 745 789 671 687 700 636 726 691 657 619 649 585 579 470 522 534
#  563 445 511 569 572 513 532 456 426 497 379 384 399 279 289 276 268 271
#  223 170 150 154 177 140 126 114 121  97  86  80  59  48  44  43  28  29
#   22  15  13  12   5   8   5   4   2   3   7]

# %%
import numpy as np
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype=int) #numpy활용해 수정

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역의 인구 구조')
plt.plot(home)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %%
import numpy as np
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype=int) / int(row[2])

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역의 인구 구조')
plt.plot(home)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림

# %%
#추가문제 두지역의 그래프를 동시에 그리는 방법
import numpy as np
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)


name1 = input('인구 구조가 알고 싶은 첫 번째 지역의 이름(읍면동 단위)을 입력해주세요 : ')
name2 = input('인구 구조가 알고 싶은 두 번째 지역의 이름(읍면동 단위)을 입력해주세요 : ')

for row in data :
    if name1 in row[0] :
        first = np.array(row[3:], dtype=int) / int(row[2])
    if name2 in row[0] :
        second = np.array(row[3:], dtype=int) / int(row[2])
    
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title(name1+'지역과 '+name2+' 지역의 인구 구조 비교')
plt.plot(first, label=name1)
plt.plot(second, label=name2)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 첫 번째 지역의 이름(읍면동 단위)을 입력해주세요 : 강남구
# 인구 구조가 알고 싶은 두 번째 지역의 이름(읍면동 단위)을 입력해주세요 : 노원구

# %%
import numpy as np
import csv

#데이터를 읽어온다
f=open('age.csv')
data=csv.reader(f)
next(data)
data = list(data)

#궁금한 지역의 이름을 입력받는다
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
mn = 1
result_name = ''
result = 0

#궁금한 지역의 인구구조를 저장한다
for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype=int) / int(row[2])
        
#궁금한 지역의 인구구조와 가장 비슷한 인구구조를 가진 지역을 찾는다
for row in data :
    away = np.array(row[3:], dtype=int) / int(row[2])
    s = np.sum((home-away)**2)
    if s < mn and name not in row[0] :
        mn = s
        result_name = row[0]
        result = away

#궁금한 지역의 인구구조와 가장 비슷한 곳의 인구구조를 시각화한다
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name+'지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result, label = result_name)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 신도림
