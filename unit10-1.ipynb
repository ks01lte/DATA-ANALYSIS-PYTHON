# %%
import csv
f = open('gender.csv')
data = csv.reader(f)
m=[]
f=[]

name = input('궁금한 동네를 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) :
            m.append(int(row[i])) #남성 데이터 저장하기
            f.append(int(row[i+103])) #여성 데이터 저장하기
        break
        
import matplotlib.pyplot as plt
plt.plot(m, label = 'Male')
plt.plot(f, label = 'Female')
plt.legend()
plt.show()

# %%
# 남성 인구에서 여성 인구를 뺀 값을 result 리스트로 추가

import csv
f = open('gender.csv')
data = csv.reader(f)
result = []

name = input('궁금한 동네를 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) :
            result.append(int(row[i])-int(row[i+103])) #남성인구수-여성인구수를 result 리스트에 저장
        break
        
import matplotlib.pyplot as plt
plt.bar(range(101), result)
plt.show()
# Out:
# 궁금한 동네를 입력해주세요 : 제주

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #격자무늬 스타일지정
plt.scatter([1,2,3,4], [10,30,20,40])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #격자무늬 스타일지정
plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300]) #s속성을 통해 버블차트 표현
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #격자무늬 스타일지정
plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300], c=['red','blue','green','gold']) #c속성을 통해 각 점의 색상 설정
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #격자무늬 스타일지정
plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300], c=range(4))
plt.colorbar() #컬러바 추가
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #격자무늬 스타일지정
plt.scatter([1,2,3,4], [10,30,20,40], s=[100,200,250,300], c=range(4), cmap='jet') #cmap 속성을 통해 컬러바에 사용될 색상 종류 설정
plt.colorbar() #컬러바 추가
plt.show()

# %%
import matplotlib.pyplot as plt
import random
x=[]
y=[]
size=[]

for i in range(100) :
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))

plt.style.use('ggplot')
plt.scatter(x,y, s=size, c=size, cmap='jet', alpha=0.7)
plt.colorbar()
plt.show()

# %%
import csv
import math
f = open('gender.csv')
data = csv.reader(f)
m=[]
f=[]
size=[]

name = input('궁금한 동네를 입력해주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) :
            m.append(int(row[i])) #남성 데이터 저장하기
            f.append(int(row[i+103])) #여성 데이터 저장하기
            size.append(math.sqrt(int(row[i])+int(row[i+103])))
        break
        
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='Malgun Gothic')
plt.figure(figsize=(10,5),dpi=300)
plt.title(name+ '지역의 성별 인구 그래프')
plt.scatter(m,f, s=size, c=range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)), range(max(m)), 'g')
plt.xlabel('남성 인구 수')
plt.ylabel('여성 인구 수')
plt.show()
# Out:
# 궁금한 동네를 입력해주세요 : 제주
